# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiakashaya/DATA_SCIENCE/blob/main/regex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !kaggle datasets download rtatman/digidb
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/rtatman/digidb
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 14.3k/14.3k [00:00<00:00, 42.3MB/s]

# %%
# !unzip digidb.zip
# Out:
# Archive:  digidb.zip
#   inflating: DigiDB_digimonlist.csv
#   inflating: DigiDB_movelist.csv
#   inflating: DigiDB_supportlist.csv

# %%
ls-ltr  /content
# Out:
# total 136
# -rw-r--r-- 1 root root 14671 Sep 20  2019 digidb.zip
# -rw-r--r-- 1 root root  5158 Sep 20  2019 DigiDB_supportlist.csv
# -rw-r--r-- 1 root root 39386 Sep 20  2019 DigiDB_movelist.csv
# -rw-r--r-- 1 root root 15354 Sep 20  2019 DigiDB_digimonlist.csv
# drwxr-xr-x 1 root root  4096 Jun  4 13:32 sample_data/
# -rwxrwxrwx 1 root root 40042 Jun 13 04:11 student_mental_health_hybrid_learning.csv*
# -rw-r--r-- 1 root root 11989 Jun 13 04:11 mindbridge-2023-student-mental-health-survey.zip

# %%
# !chmod 777 DigiDB_supportlist.csv

# %%
import pandas as pd
df = pd.read_csv('DigiDB_supportlist.csv')
df.head()
# Out:
#                Name                                        Description
# 0     Adroit Wisdom                              Increases INT by 15%.
# 1       All-Rounder             Increases ATK, DEF, INT and SPD by 5%.
# 2           Analyze                      Increases scan values by 10%.
# 3  Animal Colosseum         Increases damage from Earth skills by 15%.
# 4      Aus Generics  Increases SPD and EVA by 25% when HP drops bel...

# %%
import numpy as np
import matplotlib.pyplot as plt

m1 = df['Name'].str.len() # Calculate the length of names from the 'Name' column

plt.hist(m1, color="violet", bins=10, edgecolor="black")
plt.title("Distribution of Name Lengths in Support List")
plt.xlabel("Name Length")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# # New Section
