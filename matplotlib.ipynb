# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiakashaya/DATA_SCIENCE/blob/main/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !kaggle datasets download aamir28/mindbridge-2023-student-mental-health-survey
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/aamir28/mindbridge-2023-student-mental-health-survey
# License(s): CC-BY-SA-4.0
# ...
# 100% 11.7k/11.7k [00:00<00:00, 36.5MB/s]

# %%
# !unzip mindbridge-2023-student-mental-health-survey.zip
# Out:
# Archive:  mindbridge-2023-student-mental-health-survey.zip
#   inflating: student_mental_health_hybrid_learning.csv

# %%
# !chmod 777 mindbridge-2023-student-mental-health-survey
# Out:
# chmod: cannot access 'mindbridge-2023-student-mental-health-survey': No such file or directory

# %%
ls-ltr /content
# Out:
# total 56
# drwxr-xr-x 1 root root  4096 Jun  4 13:32 sample_data/
# -rw-r--r-- 1 root root 40042 Jun 13 04:11 student_mental_health_hybrid_learning.csv
# -rw-r--r-- 1 root root 11989 Jun 13 04:11 mindbridge-2023-student-mental-health-survey.zip

# %%
# !chmod 777 student_mental_health_hybrid_learning.csv

# %%
import pandas as pd
df = pd.read_csv("student_mental_health_hybrid_learning.csv")
df.head()
# Out:
#   student_id  age             gender  year_of_study major_category  \
# 0    STU1001   22             Female              3       Business
# 1    STU1002   19                  M              2       Business
# 2    STU1003   23  Prefer not to say              3           STEM
# 3    STU1004   23               Male              2     Humanities
# 4    STU1005   17             Female              5           Arts
#
#    daily_sleep_hours  daily_screen_time_hours  \
# 0                6.1                      4.1
# 1                7.0                      2.3
# 2                5.0                      9.2
# 3                3.8                      2.0
# 4                5.8                      4.1
#
#    physical_activity_days_per_week  phq9_score  gad7_score  \
# 0                                1        17.0        16.0
# 1                                3         9.0         7.0
# 2                                1         1.0         2.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("student_mental_health_hybrid_learning.csv")

plt.figure(figsize=(10, 8))
correlation_matrix = df.select_dtypes(include=['number']).corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Student Mental Health Factors', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # New Section
