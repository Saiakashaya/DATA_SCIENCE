# %% [markdown]
# <a href="https://colab.research.google.com/github/Saiakashaya/DATA_SCIENCE/blob/main/zscore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle

# %%
# !kaggle datasets download rtatman/digidb
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/rtatman/digidb
# License(s): CC-BY-NC-SA-4.0
# ...
# 100% 14.3k/14.3k [00:00<00:00, 27.2MB/s]

# %%
ls-ltr /content
# Out:
# total 20
# -rw-r--r-- 1 root root 14671 Sep 20  2019 digidb.zip
# drwxr-xr-x 1 root root  4096 Jun  4 13:32 sample_data/

# %%
# !unzip digidb.zip
# Out:
# Archive:  digidb.zip
#   inflating: DigiDB_digimonlist.csv
#   inflating: DigiDB_movelist.csv
#   inflating: DigiDB_supportlist.csv

# %%
# !chmod 777 DigiDB_supportlist.csv

# %%
import pandas as pd
df = pd.read_csv("DigiDB_supportlist.csv")
df.head()
# Out:
#                Name                                        Description
# 0     Adroit Wisdom                              Increases INT by 15%.
# 1       All-Rounder             Increases ATK, DEF, INT and SPD by 5%.
# 2           Analyze                      Increases scan values by 10%.
# 3  Animal Colosseum         Increases damage from Earth skills by 15%.
# 4      Aus Generics  Increases SPD and EVA by 25% when HP drops bel...

# %%
from scipy.stats import zscore
import numpy as np
data=pd.read_csv("DigiDB_supportlist.csv")
data.head()
# Out:
#                Name                                        Description
# 0     Adroit Wisdom                              Increases INT by 15%.
# 1       All-Rounder             Increases ATK, DEF, INT and SPD by 5%.
# 2           Analyze                      Increases scan values by 10%.
# 3  Animal Colosseum         Increases damage from Earth skills by 15%.
# 4      Aus Generics  Increases SPD and EVA by 25% when HP drops bel...

# %%
data['description_length'] = data['Description'].apply(len)
score = zscore(data['description_length'])
score
# Out:
# array([-1.34045437, -0.40813073, -0.90171383, -0.18876046,  0.41450777,
#         1.51135911, -0.02423276,  1.78557195, -1.34045437, -0.07907533,
#        -0.90171383,  0.46935034, -0.90171383, -0.18876046,  0.41450777,
#        -0.2984456 ,  0.46935034, -0.90171383, -0.24360303, -1.34045437,
#         1.12746114,  0.96293344, -0.24360303, -1.39529694, -1.34045437,
#        -0.02423276, -0.90171383, -1.6146672 ,  0.30482264, -1.66950977,
#         1.73072938,  1.45651655,  0.90809088,  1.34683141, -1.34045437,
#        -0.24360303, -1.55982464,  1.18230371, -0.4629733 ,  0.90809088,
#        -1.50498207, -0.51781586, -1.34045437, -0.7920287 , -0.18876046,
#         1.01777601, -0.07907533,  1.62104425,  1.73072938, -0.68234357,
#        -0.02423276, -0.02423276, -0.7920287 ,  0.35966521,  1.51135911,
#         0.35966521, -0.2984456 ,  0.14029494,  0.30482264, -0.18876046,
#        -0.24360303, -1.4501395 ,  1.18230371, -0.68234357,  2.22431248,
# ...
